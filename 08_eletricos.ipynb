# %% [markdown]
# ## Ônibus elétricos

# %% [markdown]
# Nesse notebook é feita uma análise dos ônibus elétricos

# %% [markdown]
# Os dados foram disponibilizados pela SMT e incluídos manualmente na pasta "data" do projeto

# %%
import pandas as pd
from utils.load_csv import load_csv

# %%
df_eletricos = load_csv('Ônibus elétricos a bateria - 15 09 2025 - última(POR LOTE).csv', skiprows=4)

#df_eletricos = df_eletricos.dropna(axis=1, how="all")

#df_eletricos = df_eletricos.dropna(axis=0, how="all")

# %%
df_eletricos
# Out:
#      Lote    Empresa                         Prefixo               Placa  \
# 0    AR0   Ambiental                           41100            GEV7G11
# 1    AR0   Ambiental                           41101            ELI8D71
# 2    AR0   Ambiental                           41102            FIP5C12
# 3    AR0   Ambiental                           41103            FJQ3D62
# 4    AR0   Ambiental                           41104            FYE4E53
# ..    ...        ...                             ...                 ...
# 768   NaN        NaN                             D12          AUTO BLESS
# 769   NaN        NaN                             D12  AUTO BLESS - Teste
# 770   NaN        NaN                             D13        ALFA RODOBUS
# 771   NaN        NaN  TOTAL GRUPO LOCAL DISTRIBUIÇÃO                 NaN
# 772   NaN        NaN                     TOTAL GERAL                 NaN
#
#                  Chassi Data de Inclusão Tipo de Vínculo   Tecnologia  \
# ...
